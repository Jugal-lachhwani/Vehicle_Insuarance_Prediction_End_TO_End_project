# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Vehicle_Insuarance_Predictor"
COLLECTION_NAME = "Vehicle-Insuarance-Data"
CONNECTION_URL = "mongodb+srv://jugallachhwani15_db_user:Jugal@12345@cluster0.pyvcisb.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]
# Out:
# ---------------------------------------------------------------------------
# InvalidURI                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client = pymongo.MongoClient(CONNECTION_URL)
#       2 data_base = client[DB_NAME]
#       3 collection = data_base[COLLECTION_NAME]
#
# File c:\Users\DELL\miniconda3\envs\vehichle\Lib\site-packages\pymongo\synchronous\mongo_client.py:804, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     799 for entity in self._host:
#     800     # A hostname can only include a-z, 0-9, '-' and '.'. If we find a '/'
#     801     # it must be a URI,
#     802     # https://en.wikipedia.org/wiki/Hostname#Restrictions_on_valid_host_names
#     803     if "/" in entity:
# --> 804         res = _validate_uri(
#     805             entity,
#     806             port,
#     807             validate=True,
#     808             warn=True,
# ...

# %%
import pymongo
from urllib.parse import quote_plus

DB_NAME = "Vehicle_Insuarance_Predictor"
COLLECTION_NAME = "Vehicle-Insuarance-Data"

username = "jugallachhwani15_db_user"
password = "Jugal@12345"
password_encoded = quote_plus(password)

CONNECTION_URL = f"mongodb+srv://{username}:{password_encoded}@cluster0.pyvcisb.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

print("Connected successfully!")
# Out:
# Connected successfully!

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)

# %%
# Load back data from mongodb

df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
#                         _id  id Gender  Age  Driving_License  Region_Code  \
# 0  68ed548236af361ab37b0975   1   Male   44                1         28.0
# 1  68ed548236af361ab37b0976   2   Male   76                1          3.0
#
#    Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 0                   0   > 2 Years            Yes         40454.0
# 1                   0    1-2 Year             No         33536.0
#
#    Policy_Sales_Channel  Vintage  Response
# 0                  26.0      217         1
# 1                  26.0      183         0
